# %% [markdown]
# # Scraping Script for بيوت in Riyadh

# %%
#importing library for scraping
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import random
import json
import os

# %%
url="https://www.bayut.sa/en/for-sale/properties/riyadh/"
page=requests.get(url)
soup=BeautifulSoup(page.text,'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find('div', class_='_475e888a')
# Out:
# <div class="_475e888a"><div class="_73e5aa2c"><div class="dca7f822"><div class="_6ed5f9fa"><div aria-label="Label" class="ee209838"><img alt="" aria-label="Signature" class="f1f78be0" src="/assets/iconCardLabelDefaultSignatureEN_noinline.62dd4baa7f1ebe59a26505ce26299410.svg"/></div></div></div></div><h4 class="_0e3d05b8 _5d2c9c26"><div class="_2923a568"><span aria-label="Currency" class="dc381b54">‎﷼‎</span><span class="_9e0180f9"></span><span aria-label="Price" class="dc381b54">1,549,000</span></div></h4><div class="_5cbe8e5a"><div class="_948d9e0a d7383df5"><div class="_948d9e0a d05e0d48"><span class="_1822ec30 f34d293d"><span aria-label="Type" class="_19e94678 e0abc2de">Floor</span></span><div class="e9953518"></div><span class="_1822ec30 f34d293d"><span class="_46a367d3 _18fde93a"></span><span aria-label="Beds" class="_19e94678 e0abc2de">3</span></span><span class="_1822ec30 f34d293d"><span class="_46a367d3 _30bf627c"></span><span aria-label="Baths" class="_19e94678 e0abc2de">3</
# ...

# %%
soup.find('div', class_='_475e888a')
# Out:
# <div class="_475e888a"><div class="_73e5aa2c"><div class="dca7f822"><div class="_6ed5f9fa"><div aria-label="Label" class="ee209838"><img alt="" aria-label="Signature" class="f1f78be0" src="/assets/iconCardLabelDefaultSignatureEN_noinline.62dd4baa7f1ebe59a26505ce26299410.svg"/></div></div></div></div><h4 class="_0e3d05b8 _5d2c9c26"><div class="_2923a568"><span aria-label="Currency" class="dc381b54">‎﷼‎</span><span class="_9e0180f9"></span><span aria-label="Price" class="dc381b54">1,549,000</span></div></h4><div class="_5cbe8e5a"><div class="_948d9e0a d7383df5"><div class="_948d9e0a d05e0d48"><span class="_1822ec30 f34d293d"><span aria-label="Type" class="_19e94678 e0abc2de">Floor</span></span><div class="e9953518"></div><span class="_1822ec30 f34d293d"><span class="_46a367d3 _18fde93a"></span><span aria-label="Beds" class="_19e94678 e0abc2de">3</span></span><span class="_1822ec30 f34d293d"><span class="_46a367d3 _30bf627c"></span><span aria-label="Baths" class="_19e94678 e0abc2de">3</
# ...

# %%
soup.find('span', {"aria-label": "Price"}).text.strip()
# Out:
# '1,549,000'

# %%
from bs4 import BeautifulSoup

# Sample HTML (Replace this with your actual page source)
html_content = """ <div class="_475e888a"><div class="_73e5aa2c"><div class="dca7f822"><div class="_6ed5f9fa"><div class="ee209838" aria-label="Label"><img src="/assets/iconCardLabelDefaultPremiumEN_noinline.500814228b136464bd68651d5f378d1a.svg" class="f1f78be0" alt="" aria-label="Premium"></div></div></div></div><h4 class="_0e3d05b8 _5d2c9c26"><div class="_2923a568"><span class="dc381b54" aria-label="Currency">&lrm;﷼&lrm;</span><span class="_9e0180f9"></span><span class="dc381b54" aria-label="Price">3,000,000</span></div></h4><div class="_5cbe8e5a"><div class="_948d9e0a d7383df5"><div class="_948d9e0a d05e0d48"><span class="_1822ec30 f34d293d"><span class="_19e94678 e0abc2de" aria-label="Type">Villa</span></span><div class="e9953518"></div><span class="_1822ec30 f34d293d"><span class="_46a367d3 _18fde93a"></span><span class="_19e94678 e0abc2de" aria-label="Beds">7</span></span><span class="_1822ec30 f34d293d"><span class="_46a367d3 _30bf627c"></span><span class="_19e94678 e0abc2de" aria-label="Baths">5</span></span><div class="e9953518"></div><span class="_1822ec30 f34d293d _83f41a1c"><span class="f314b956">Area:</span><span class="_19e94678 f8d4dd58" aria-label="Area"><h4 class="cfac7e1b _85ddb82f">850 Sq. M.</h4></span></span></div></div><h2 dir="auto" aria-label="Title" class="f0f13906" id="active_title">7 Bedroom Villa For Sale in Al Nudwah, Riyadh</h2><div aria-label="Location" class="_948d9e0a _371e9918"><div class="df38b004"></div><h3 class="_4402bd70">Al Nadwa District, East Riyadh, Riyadh</h3></div></div><div class="_8a7d9294"><button class="_9f343c7a d840b00f da3adf89 _6a7bb9d3" aria-label="Send email"><svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" class="b12480ab"><path d="M13.3 2.7H2.7A1.3 1.3 0 0 0 1.3 4v8a1.3 1.3 0 0 0 1.4 1.3h10.6a1.3 1.3 0 0 0 1.4-1.3V4a1.3 1.3 0 0 0-1.4-1.3zm0 2.6L8 8.7 2.7 5.3V4L8 7.3 13.3 4z"></path><path fill="none" d="M0 0h16v16H0z"></path></svg><span class="_7982fc6c"> Email </span></button><button class="_9f343c7a a2c630ea df52fb31 ab668ac7" aria-label="Call"><svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" class="b12480ab"><path d="M13.3 10.3A7.6 7.6 0 0 1 11 10a.7.7 0 0 0-.7.1l-1 1.4a10.1 10.1 0 0 1-4.6-4.6L6 5.7A.7.7 0 0 0 6 5a7.4 7.4 0 0 1-.3-2.3A.7.7 0 0 0 5 2H2.8c-.4 0-.8.2-.8.7A11.4 11.4 0 0 0 13.3 14a.7.7 0 0 0 .7-.8V11a.7.7 0 0 0-.7-.6z"></path></svg><span class="_7982fc6c"> Call </span></button><button class="_3eb95c08 _52ab7901 d1961d93 b871a59a _1d84ccea" aria-label="Whatsapp"><svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24" class="_6f3a001f"><path fill-rule="evenodd" d="M19.2 4.8A10.2 10.2 0 0 0 3.2 17l-1.4 5.3L7.2 21a10.1 10.1 0 0 0 4.8 1 10.2 10.2 0 0 0 7.2-17.3zM12 20.4a8.4 8.4 0 0 1-4.3-1.2h-.3l-3.2.7 1-3.1-.3-.3a8.4 8.4 0 1 1 7.1 4zm4.7-6.3c-.3-.1-1.5-.8-1.8-.8s-.4-.2-.5 0l-.8 1c-.1 0-.3.3-.6.2a7 7 0 0 1-2-1.3 7.7 7.7 0 0 1-1.4-1.8c-.2-.2 0-.4 0-.5l.5-.4a1.7 1.7 0 0 0 .2-.5.5.5 0 0 0 0-.4l-.8-2c-.2-.4-.4-.3-.6-.3h-.4a1 1 0 0 0-.7.3 2.9 2.9 0 0 0-1 2A5 5 0 0 0 8 12.4a11.3 11.3 0 0 0 4.4 4 14.5 14.5 0 0 0 1.4.4 3.4 3.4 0 0 0 1.6 0 2.6 2.6 0 0 0 1.7-1 2.1 2.1 0 0 0 .2-1.3l-.5-.3z"></path></svg></button></div><div class="_948d9e0a _95d4067f"></div></div> """

soup = BeautifulSoup(html_content, "html.parser")

# Extracting details
price = soup.find("span", {"aria-label": "Price"}).text.strip()
currency = soup.find("span", {"aria-label": "Currency"}).text.strip()
property_type = soup.find("span", {"aria-label": "Type"}).text.strip()
bedrooms = soup.find("span", {"aria-label": "Beds"}).text.strip()
bathrooms = soup.find("span", {"aria-label": "Baths"}).text.strip()
area = soup.find("h4", class_="cfac7e1b _85ddb82f").text.strip()
title = soup.find("h2", {"aria-label": "Title"}).text.strip()
location = soup.find("h3", class_="_4402bd70").text.strip()

# Printing extracted data
print(f"Title: {title}")
print(f"Price: {currency} {price}")
print(f"Property Type: {property_type}")
print(f"Bedrooms: {bedrooms}")
print(f"Bathrooms: {bathrooms}")
print(f"Area: {area}")
print(f"Location: {location}")
# Out:
# Title: 7 Bedroom Villa For Sale in Al Nudwah, Riyadh
# Price: ‎﷼‎ 3,000,000
# Property Type: Villa
# Bedrooms: 7
# Bathrooms: 5
# Area: 850 Sq. M.
# Location: Al Nadwa District, East Riyadh, Riyadh

# %%
def extract_property_details(url):
    df = pd.DataFrame(columns=["Title", "Price", "Property Type", "Bedrooms", "Bathrooms", "Area", "Location"])
    for i in range(290):
        response = requests.get(f"https://www.bayut.sa/en/for-sale/properties/riyadh/page-{i}/")
        soup = BeautifulSoup(response.text, "html.parser")
        properties = soup.find_all("div", class_="_475e888a")
        for prop in properties:
            Title = prop.find("h2", {"aria-label": "Title"}).text.strip() if prop.find("h2", {"aria-label": "Title"}) else "N/A"
            Price = prop.find("span", {"aria-label": "Price"}).text.strip() if prop.find("span", {"aria-label": "Price"}) else "N/A"
            Property_Type = prop.find("span", {"aria-label": "Type"}).text.strip() if prop.find("span", {"aria-label": "Type"}) else "N/A"
            Bedrooms = prop.find("span", {"aria-label": "Beds"}).text.strip() if prop.find("span", {"aria-label": "Beds"}) else "N/A"
            Bathrooms = prop.find("span", {"aria-label": "Baths"}).text.strip() if prop.find("span", {"aria-label": "Baths"}) else "N/A"
            Area = prop.find("h4", class_="cfac7e1b _85ddb82f").text.strip() if prop.find("h4", class_="cfac7e1b _85ddb82f") else "N/A"
            Location = prop.find("h3", class_="_4402bd70").text.strip() if prop.find("h3", class_="_4402bd70") else "N/A"
            
            df.loc[len(df)] = [Title, Price, Property_Type, Bedrooms, Bathrooms, Area, Location]
        print(f"Page {i} scraped successfully.")
        time.sleep(random.uniform(1, 3))# Random sleep to avoid being blocked
    df.to_csv("bayut_properties.csv", index=False)

# %%
extract_property_details(url)
# Out:
# Page 0 scraped successfully.
# Page 1 scraped successfully.
# Page 2 scraped successfully.
# Page 3 scraped successfully.
# Page 4 scraped successfully.
# Page 5 scraped successfully.
# Page 6 scraped successfully.
# Page 7 scraped successfully.
# Page 8 scraped successfully.
# Page 9 scraped successfully.
# Page 10 scraped successfully.
# Page 11 scraped successfully.
# Page 12 scraped successfully.
# Page 13 scraped successfully.
# Page 14 scraped successfully.
# Page 15 scraped successfully.
# Page 16 scraped successfully.
# Page 17 scraped successfully.
# Page 18 scraped successfully.
# Page 19 scraped successfully.
# Page 20 scraped successfully.
# Page 21 scraped successfully.
# Page 22 scraped successfully.
# Page 23 scraped successfully.
# Page 24 scraped successfully.
# Page 25 scraped successfully.
# Page 26 scraped successfully.
# Page 27 scraped successfully.
# Page 28 scraped successfully.
# Page 29 scraped successfully.
# Page 30 scraped successfully.
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set up Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode
service = Service("/opt/homebrew/bin/chromedriver")  # Replace with the path to your ChromeDriver
driver = webdriver.Chrome(service=service, options=chrome_options)

# Navigate to the URL
driver.get(url)

# Extract property details using Selenium
properties = driver.find_elements(By.CLASS_NAME, "_475e888a")
for prop in properties:
    try:
        title = prop.find_element(By.CSS_SELECTOR, 'h2[aria-label="Title"]').text.strip()
    except:
        title = "N/A"
    try:
        price = prop.find_element(By.CSS_SELECTOR, 'span[aria-label="Price"]').text.strip()
    except:
        price = "N/A"
    try:
        property_type = prop.find_element(By.CSS_SELECTOR, 'span[aria-label="Type"]').text.strip()
    except:
        property_type = "N/A"
    try:
        bedrooms = prop.find_element(By.CSS_SELECTOR, 'span[aria-label="Beds"]').text.strip()
    except:
        bedrooms = "N/A"
    try:
        bathrooms = prop.find_element(By.CSS_SELECTOR, 'span[aria-label="Baths"]').text.strip()
    except:
        bathrooms = "N/A"
    try:
        area = prop.find_element(By.CSS_SELECTOR, 'h4.cfac7e1b._85ddb82f').text.strip()
    except:
        area = "N/A"
    try:
        location = prop.find_element(By.CSS_SELECTOR, 'h3._4402bd70').text.strip()
    except:
        location = "N/A"

    # Print extracted data
    print(f"Title: {title}")
    print(f"Price: {price}")
    print(f"Property Type: {property_type}")
    print(f"Bedrooms: {bedrooms}")
    print(f"Bathrooms: {bathrooms}")
    print(f"Area: {area}")
    print(f"Location: {location}")
    print("-" * 50)

# Close the WebDriver
driver.quit()
# Out:
# Title: 3 Bedrooms Floor For Sale in Al Olaya, Riyadh
# Price: 1,549,000
# Property Type: Floor
# Bedrooms: 3
# Bathrooms: 3
# Area: 175 Sq. M.
# Location: Al Olaya, North Riyadh, Riyadh
# --------------------------------------------------
# Title: Apartment For Sale in Al Khalij, Riyadh
# Price: 990,000
# Property Type: Apartment
# Bedrooms: 5
# Bathrooms: 2
# Area: 194 Sq. M.
# Location: Al Khaleej, East Riyadh, Riyadh
# --------------------------------------------------
# Title: Residential land for sale in Al Manakh, south of Riyadh
# Price: 350,002
# Property Type: Residential Land
# Bedrooms: N/A
# Bathrooms: N/A
# Area: 253 Sq. M.
# Location: Al Manakh, South Riyadh, Riyadh
# --------------------------------------------------
# Title: Apartment in East Riyadh，Al Janadriyah 4 bedrooms 950000 SAR - 87616329
# Price: 950,000
# Property Type: Apartment
# Bedrooms: 4
# Bathrooms: 3
# Area: 188 Sq. M.
# Location: Al Janadriyah, East Riyadh, Riyadh
# ...

# %%
def extract_property_details_selenium(driver, url):
    df = pd.DataFrame(columns=["Title", "Price", "Property Type", "Bedrooms", "Bathrooms", "Area", "Location"])
    for i in range(1, 3):  # Assuming there are 290 pages
        driver.get(f"{url}page-{i}/")
        time.sleep(random.uniform(1, 3))  # Random sleep to avoid being blocked
        properties = driver.find_elements(By.CLASS_NAME, "_475e888a")
        for prop in properties:
            try:
                title = prop.find_element(By.CSS_SELECTOR, 'h2[aria-label="Title"]').text.strip()
            except:
                title = "N/A"
            try:
                price = prop.find_element(By.CSS_SELECTOR, 'span[aria-label="Price"]').text.strip()
            except:
                price = "N/A"
            try:
                property_type = prop.find_element(By.CSS_SELECTOR, 'span[aria-label="Type"]').text.strip()
            except:
                property_type = "N/A"
            try:
                bedrooms = prop.find_element(By.CSS_SELECTOR, 'span[aria-label="Beds"]').text.strip()
            except:
                bedrooms = "N/A"
            try:
                bathrooms = prop.find_element(By.CSS_SELECTOR, 'span[aria-label="Baths"]').text.strip()
            except:
                bathrooms = "N/A"
            try:
                area = prop.find_element(By.CSS_SELECTOR, 'h4.cfac7e1b._85ddb82f').text.strip()
            except:
                area = "N/A"
            try:
                location = prop.find_element(By.CSS_SELECTOR, 'h3._4402bd70').text.strip()
            except:
                location = "N/A"

            # Append the extracted data to the DataFrame
            df.loc[len(df)] = [title, price, property_type, bedrooms, bathrooms, area, location]
        print(f"Page {i} scraped successfully.")
    df.to_csv("bayut_properties_selenium.csv", index=False)

# %%
url
# Out:
# 'https://www.bayut.sa/en/for-sale/properties/riyadh/'

# %%
extract_property_details_selenium(driver, url)
